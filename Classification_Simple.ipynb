# %% [markdown]
# <a href="https://colab.research.google.com/github/3nxinlovespotato/AI-Project-1/blob/main/48_2_Classification_complete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.tree import DecisionTreeClassifier
import pandas as pd

from sklearn.model_selection import train_test_split

# mse mses CANNOT CUZ ITS REGRESSION
from sklearn.metrics import accuracy_score

# transforming data, makes ML easier to learn
from sklearn.preprocessing import LabelEncoder # it will recognise string and convert it into numbers

# %%
data = {
    'Plays Sports': ['Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No'],
    'Drinks Coffee': ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No'],
    'Age': [7, 12, 18, 35, 38, 50, 83],
    'Enjoys Hiking': ['No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No']
}

# %%
df = pd.DataFrame(data)
df
# Out:
#   Plays Sports Drinks Coffee  Age Enjoys Hiking
# 0          Yes           Yes    7            No
# 1          Yes            No   12            No
# 2           No           Yes   18           Yes
# 3           No           Yes   35           Yes
# 4          Yes           Yes   38           Yes
# 5          Yes            No   50            No
# 6           No            No   83            No

# %%
label_encoders = {}
# changing categorical values (Yes/No) into (1/0)
# why we do it?
# 1. ML models need numbers (most ML algorithms cant handle non-numeric data directly)
# 2. Efficiency in processing (simpligies data processing)
for column in ['Plays Sports', 'Drinks Coffee', 'Enjoys Hiking']:
    le = LabelEncoder()
    df[column] = le.fit_transform(df[column])
    label_encoders[column] = le

print(label_encoders)
# Out:
# {'Plays Sports': LabelEncoder(), 'Drinks Coffee': LabelEncoder(), 'Enjoys Hiking': LabelEncoder()}

# %%
X = df[['Plays Sports', 'Drinks Coffee', 'Age']]
y = df['Enjoys Hiking']

# %%
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
# Plot the decision tree
plt.figure(figsize=(12, 8))
plot_tree(
    clf,
    feature_names=['Plays Sports', 'Drinks Coffee', 'Age'],
    class_names=label_encoders['Enjoys Hiking'].classes_,
    filled=True,
    fontsize=12
)
plt.show()
